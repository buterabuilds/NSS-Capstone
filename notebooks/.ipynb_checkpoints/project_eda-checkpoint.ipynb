# %%
import requests
import json

# %%
with open('../secrets.json') as fi:
    creds = json.load(fi)

api_key = creds['API_KEY']

# %%
endpoint = 'https://api.census.gov/data/timeseries/intltrade/exports/statenaics'

params = {
    'get': 'STATE,ALL_VAL_YR,NAICS,NAICS_LDESC',
    'key': '967df49e6ee60d389b368729bbe1a385e2698630',
    'time': 'from+2010-01+to+2026-01',
    'COMM_LVL': 'NA2'
}

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:120.0) Gecko/20100101 Firefox/120.0",
    "Accept": "application/json, text/plain, */*"
}

# %%
response = requests.get(endpoint, params = params, headers=headers)

# %%
import pandas as pd

# %%
df = pd.read_json('../data/exports_statenaics.json')

# %%
df.columns = df.iloc[0]
df = df[1:]

df = df.reset_index(drop=True)

# %%
df.to_csv('census_exports.csv', index=False)
